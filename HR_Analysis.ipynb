# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\bhuva\Downloads\Cleaned_HR_Data_Analysis.csv")

# %%
df.head()
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 3         3430  21-Jun-21       Area Sales Manager         CCDR
# 4         3431  29-Jun-19       Area Sales Manager          TNS
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# 2         Active    Full-Time  Zone B                  Part-Time
# 3         Active     Contract  Zone A                  Full-Time
# 4         Active     Contract  Zone A                  Temporary
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# ...

# %%
df.columns
# Out:
# Index(['Employee ID', 'StartDate', 'Title', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'DepartmentType', 'Division', 'DOB', 'State', 'GenderCode', 'RaceDesc',
#        'MaritalDesc', 'Performance Score', 'Current Employee Rating',
#        'Survey Date', 'Engagement Score', 'Satisfaction Score',
#        'Work-Life Balance Score', 'Training Date', 'Training Program Name',
#        'Training Type', 'Training Outcome', 'Training Duration(Days)',
#        'Training Cost', 'Age'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df.tail()
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 2840         3421  09-May-22  Production Technician I           PL
# 2841         3423  28-Dec-20  Production Technician I          SVG
# 2842         3424  09-Dec-20  Production Technician I          TNS
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 2840         Active    Part-Time  Zone A                  Part-Time
# 2841         Active    Part-Time  Zone A                  Full-Time
# 2842     Terminated     Contract  Zone B                  Temporary
# 2843     Terminated     Contract  Zone B                  Full-Time
# 2844         Active    Full-Time  Zone B                  Temporary
#
#          DepartmentType               Division         DOB State GenderCode  \
# ...

# %%
df.isnull().sum()
# Out:
# Employee ID                   0
# StartDate                     0
# Title                         0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# GenderCode                    0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Survey Date                   0
# Engagement Score              0
# Satisfaction Score            0
# Work-Life Balance Score       0
# Training Date                 0
# Training Program Name         0
# Training Type                 0
# Training Outcome              0
# Training Duration(Days)       0
# Training Cost                 0
# Age                           0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
sns.countplot(x = 'GenderCode', data = df, color = 'brown')
# Out:
# <Axes: xlabel='GenderCode', ylabel='count'>

# %%
sns.countplot(x = 'MaritalDesc', data = df, color = 'brown')
# Out:
# <Axes: xlabel='MaritalDesc', ylabel='count'>

# %%
sns.countplot(x = 'Training Outcome' , data = df, order = df['Training Outcome'].value_counts().index , color = 'orange')
# Out:
# <Axes: xlabel='Training Outcome', ylabel='count'>

# %%
sns.countplot(x = 'DepartmentType' , data = df, order = df['DepartmentType'].value_counts().index , color = 'violet')
plt.xticks(rotation = 45, fontsize = 10)
plt.show()

# %%
y = df['Age']
x = df['Division']
plt.figure(figsize=(8,5))
plt.xticks(rotation = 90)
plt.bar(x,y)
# Out:
# <BarContainer object of 2845 artists>

# %%
sns.countplot(df["BusinessUnit"])
plt.xlabel("count", fontsize = 20)
plt.ylabel("BusinessUnit", fontsize = 20)
plt.title("Number of Business Units")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Title', data = df, order=df['Title'].value_counts().index, color = 'red')
plt.xticks(rotation = 90, fontsize = 20)
plt.show()

# %%
sns.lineplot(data = df, x = 'Age', y ='Satisfaction Score')
# Out:
# <Axes: xlabel='Age', ylabel='Satisfaction Score'>

# %%
sns.histplot(df['Training Cost'])
# Out:
# <Axes: xlabel='Training Cost', ylabel='Count'>

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.lineplot(data = df, x = 'Age', y = 'Engagement Score',label = 'Engagement Score')
sns.lineplot(data = df ,  x = 'Age', y = 'Satisfaction Score',label = 'Satisfaction Score')
# Out:
# <Axes: xlabel='Age', ylabel='Engagement Score'>

# %%
sns.scatterplot(data = df, x = 'Age', y = 'Current Employee Rating')
# Out:
# <Axes: xlabel='Age', ylabel='Current Employee Rating'>

# %%
sns.countplot(data = df, x = 'DepartmentType', hue = 'GenderCode')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data = df, x = 'Division', hue = 'GenderCode')
plt.xticks(rotation = 45)
plt.show()

# %%
df['Training Program Name'].value_counts()
# Out:
# Training Program Name
# Communication Skills      633
# Project Management        585
# Leadership Development    544
# Technical Skills          543
# Customer Service          540
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15,4))
sns.countplot(x = 'Training Program Name', data = df, hue = 'DepartmentType')
# Out:
# <Axes: xlabel='Training Program Name', ylabel='count'>

# %%
cor = df.describe()
cor
# Out:
#        Employee ID  Current Employee Rating  Engagement Score  \
# count  2845.000000              2845.000000       2845.000000
# mean   2470.591916                 2.974692          2.941652
# std     859.450107                 1.012610          1.435230
# min    1001.000000                 1.000000          1.000000
# 25%    1736.000000                 2.000000          2.000000
# 50%    2456.000000                 3.000000          3.000000
# 75%    3197.000000                 3.000000          4.000000
# max    4000.000000                 5.000000          5.000000
#
#        Satisfaction Score  Work-Life Balance Score  Training Duration(Days)  \
# count         2845.000000              2845.000000              2845.000000
# mean             3.028471                 2.989104                 2.973989
# std              1.410067                 1.408816                 1.419682
# min              1.000000                 1.000000                 1.000000
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cor.corr(),cmap = 'coolwarm', annot = True )
plt.title("Correlation of HR Data")
plt.show()
